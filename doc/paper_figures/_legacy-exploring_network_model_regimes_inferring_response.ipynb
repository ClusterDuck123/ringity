# %%
import numpy as np
import ringity as rng
import networkx as nx
import matplotlib.pyplot as plt

from ringity.generators.utils.param_utils import (
                                            governing_equation,
                                            infer_response_parameter,
                                            beta_to_rate)

# %% [markdown]
# ## Random regime

# %%
random_state = np.random.randint(2**10)

N = 2**7

beta = np.random.uniform()
coupling = np.random.uniform()
density = np.random.uniform(0, coupling)

rate = beta_to_rate(beta)

# %%
def generate_network(return_positions = False, verbose = False):
    G = rng.network_model(
                    N = N,          
                    beta = beta,            
                    coupling = coupling,
                    density = density,
                    verbose = verbose,
                    return_positions = return_positions)
    return G

G, pos = generate_network(return_positions = True, verbose = True)
# Out:
# Response parameter was set  to: r = 0.6836994896702949
# Rate parameter was set to:   rate = 0.05990589925159485
# Coupling parameter was set to:  c = 0.5631632172476158
# Density parameter was set to: rho = 0.385487667659741
# General model detected.

# %%
layout = {node : (np.cos(t), np.sin(t)) for node, t in zip(G, pos)}

circle_x = np.cos(np.linspace(0, 2*np.pi, 100))
circle_y = np.sin(np.linspace(0, 2*np.pi, 100))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,7))
ax1.plot(circle_x, circle_y, 'gray')
rng.plot_nx(G, pos = layout, ax = ax1)
rng.plot_nx(G, ax = ax2)

# %%
r = infer_response_parameter(
                    density = density, 
                    coupling = coupling, 
                    rate = rate)

governing_equation(density = density, 
                   coupling = coupling,
                   rate = rate,
                   response = r)
# Out:
# 4.244937734654286e-13

# %% [markdown]
# ## Uniform regime ($\beta = 1$)

# %%
random_state = np.random.randint(2**10)

N = 2**7

beta = 1
coupling = np.random.uniform()
density = np.random.uniform(0, coupling)

rate = beta_to_rate(beta)

# %%
def generate_network(return_positions = False, verbose = False):
    G = rng.network_model(
                    N = N,          
                    beta = beta,            
                    coupling = coupling,
                    density = density,
                    verbose = verbose,
                    return_positions = return_positions)
    return G

G, pos = generate_network(return_positions = True, verbose = True)
# Out:
# Response parameter was set  to: r = 0.9101756427786549
# Rate parameter was set to:   rate = 0.0
# Coupling parameter was set to:  c = 0.4225477222299696
# Density parameter was set to: rho = 0.3845926446853191
# Uniform (GRGG) model detected.

# %%
layout = {node : (np.cos(t), np.sin(t)) for node, t in zip(G, pos)}

circle_x = np.cos(np.linspace(0, 2*np.pi, 100))
circle_y = np.sin(np.linspace(0, 2*np.pi, 100))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,7))
ax1.plot(circle_x, circle_y, 'gray')
rng.plot_nx(G, pos = layout, ax = ax1)
rng.plot_nx(G, ax = ax2)

# %%
r = infer_response_parameter(
                    density = density, 
                    coupling = coupling, 
                    rate = rate)

governing_equation(density = density, 
                   coupling = coupling,
                   rate = rate,
                   response = r)
# Out:
# 0.0

# %% [markdown]
# ## ER regime ($\beta = 0$)

# %%
random_state = np.random.randint(2**10)

N = 2**7

beta = 0
coupling = np.random.uniform()
density = coupling

rate = beta_to_rate(beta)

# %%
def generate_network(return_positions = False, verbose = False):
    G = rng.network_model(
                    N = N,          
                    beta = beta,            
                    coupling = coupling,
                    density = density,
                    verbose = verbose,
                    return_positions = return_positions)
    return G

G, pos = generate_network(return_positions = True, verbose = True)
# Out:
# Response parameter was set  to: r = nan
# Rate parameter was set to:   rate = inf
# Coupling parameter was set to:  c = 0.1647991471014415
# Density parameter was set to: rho = 0.1647991471014415
# Zero-distance (ER) model detected.

# %%
layout = {node : (np.cos(t), np.sin(t)) for node, t in zip(G, pos)}

circle_x = np.cos(np.linspace(0, 2*np.pi, 100))
circle_y = np.sin(np.linspace(0, 2*np.pi, 100))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,7))
ax1.plot(circle_x, circle_y, 'gray')
rng.plot_nx(G, pos = layout, ax = ax1)
rng.plot_nx(G, ax = ax2)

# %%
r = infer_response_parameter(
                    density = density, 
                    coupling = coupling, 
                    rate = rate)

governing_equation(density = density, 
                   coupling = coupling,
                   rate = rate,
                   response = r)
# Out:
# 0.0

# %% [markdown]
# ## Empty regime 2 ($c = 0$)

# %%
random_state = np.random.randint(2**10)

N = 2**7

beta = np.random.uniform()
coupling = 0
density = np.random.uniform(0, coupling)

rate = beta_to_rate(beta)

# %%
def generate_network(return_positions = False, verbose = False):
    G = rng.network_model(
                    N = N,          
                    beta = beta,            
                    coupling = coupling,
                    density = density,
                    verbose = verbose,
                    return_positions = return_positions)
    return G

G, pos = generate_network(return_positions = True, verbose = True)
# Out:
# Response parameter was set  to: r = 0.0001
# Rate parameter was set to:   rate = 5.985809399122397
# Coupling parameter was set to:  c = 0
# Density parameter was set to: rho = 0.0
# Empty2 model detected.

# %%
layout = {node : (np.cos(t), np.sin(t)) for node, t in zip(G, pos)}

circle_x = np.cos(np.linspace(0, 2*np.pi, 100))
circle_y = np.sin(np.linspace(0, 2*np.pi, 100))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,7))
ax1.plot(circle_x, circle_y, 'gray')
rng.plot_nx(G, pos = layout, ax = ax1)
rng.plot_nx(G, ax = ax2)

# %%
r = infer_response_parameter(
                    density = density, 
                    coupling = coupling, 
                    rate = rate)

governing_equation(density = density, 
                   coupling = coupling,
                   rate = rate,
                   response = r)
# Out:
# 0.0

# %% [markdown]
# ## Standard regime ($c = 1$)

# %%
random_state = np.random.randint(2**10)

N = 2**7

beta = np.random.uniform()
coupling = 1
density = np.random.uniform(0, coupling)

rate = beta_to_rate(beta)

# %%
def generate_network(return_positions = False, verbose = False):
    G = rng.network_model(
                    N = N,          
                    beta = beta,            
                    coupling = coupling,
                    density = density,
                    verbose = verbose,
                    return_positions = return_positions)
    return G

G, pos = generate_network(return_positions = True, verbose = True)
# Out:
# Response parameter was set  to: r = 0.9643640624768776
# Rate parameter was set to:   rate = 0.6165049745977833
# Coupling parameter was set to:  c = 1
# Density parameter was set to: rho = 0.965592715256845
# General model detected.

# %%
layout = {node : (np.cos(t), np.sin(t)) for node, t in zip(G, pos)}

circle_x = np.cos(np.linspace(0, 2*np.pi, 100))
circle_y = np.sin(np.linspace(0, 2*np.pi, 100))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,7))
ax1.plot(circle_x, circle_y, 'gray')
rng.plot_nx(G, pos = layout, ax = ax1)
rng.plot_nx(G, ax = ax2)

# %%
r = infer_response_parameter(
                    density = density, 
                    coupling = coupling, 
                    rate = rate)

governing_equation(density = density, 
                   coupling = coupling,
                   rate = rate,
                   response = r)
# Out:
# 9.093836794704657e-13

# %% [markdown]
# ## Empty network ($\rho = 0$)

# %%
random_state = np.random.randint(2**10)

N = 2**7

beta = np.random.uniform()
coupling = np.random.uniform()
density = 0

rate = beta_to_rate(beta)

# %%
def generate_network(return_positions = False, verbose = False):
    G = rng.network_model(
                    N = N,          
                    beta = beta,            
                    coupling = coupling,
                    density = density,
                    verbose = verbose,
                    return_positions = return_positions)
    return G

G, pos = generate_network(return_positions = True, verbose = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hr/pw6v38ln34d_87nsgcx3qjz80000gn/T/ipykernel_69218/3386512452.py in <module>
#       9     return G
#      10
# ---> 11 G, pos = generate_network(return_positions = True, verbose = True)
#
# /var/folders/hr/pw6v38ln34d_87nsgcx3qjz80000gn/T/ipykernel_69218/3386512452.py in generate_network(return_positions, verbose)
#       1 def generate_network(return_positions = False, verbose = False):
# ----> 2     G = rng.network_model(
#       3                     N = N,
#       4                     beta = beta,
#       5                     coupling = coupling,
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/ringity/generators/network_models.py in network_model(N, response, coupling, density, rate, beta, random_state, return_positions, verbose, a, r, c, alpha, rho, K)
#      46     # network_builder.set_parameters()
#      47
# ---> 48     network_builder.model_parameters.infer_missing_parameters()
#      49
#      50     if verbose:
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/ringity/classes/modelparameterbuilder.py in infer_missing_parameters(self)
#     142                                         response = self.response)
#     143             if self.response is None:
# --> 144                 self.response = infer_response_parameter(
#     145                                         density = self.density,
#     146                                         coupling = self.coupling,
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/ringity/generators/utils/param_utils.py in infer_response_parameter(density, coupling, rate)
#      28                             rate = rate
#      29                             )
# ---> 30         response = bisect(response_equation, 0.0001, 1)
#      31
#      32     return response
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/scipy/optimize/zeros.py in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     547     if rtol < _rtol:
#     548         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 549     r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     550     return results_c(full_output, r)
#     551
#
# ValueError: f(a) and f(b) must have different signs

# %%
layout = {node : (np.cos(t), np.sin(t)) for node, t in zip(G, pos)}

circle_x = np.cos(np.linspace(0, 2*np.pi, 100))
circle_y = np.sin(np.linspace(0, 2*np.pi, 100))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15,7))
ax1.plot(circle_x, circle_y, 'gray')
rng.plot_nx(G, pos = layout, ax = ax1)
rng.plot_nx(G, ax = ax2)

# %%
r = infer_response_parameter(
                    density = density, 
                    coupling = coupling, 
                    rate = rate)

governing_equation(density = density, 
                   coupling = coupling,
                   rate = rate,
                   response = r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hr/pw6v38ln34d_87nsgcx3qjz80000gn/T/ipykernel_69218/3819738413.py in <module>
# ----> 1 r = infer_response_parameter(
#       2                     density = density,
#       3                     coupling = coupling,
#       4                     rate = rate)
#       5
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/ringity/generators/utils/param_utils.py in infer_response_parameter(density, coupling, rate)
#      28                             rate = rate
#      29                             )
# ---> 30         response = bisect(response_equation, 0.0001, 1)
#      31
#      32     return response
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/scipy/optimize/zeros.py in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     547     if rtol < _rtol:
#     548         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 549     r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     550     return results_c(full_output, r)
#     551
#
# ValueError: f(a) and f(b) must have different signs

# %% [markdown]
# ## Full network $(\rho = 1)$

# %%
random_state = np.random.randint(2**10)

N = 2**7

beta = np.random.uniform()
coupling = 1
density = 1

rate = beta_to_rate(beta)

# %%
def generate_network(return_positions = False, verbose = False):
    G = rng.network_model(
                    N = N,          
                    beta = beta,            
                    coupling = coupling,
                    density = density,
                    verbose = verbose,
                    return_positions = return_positions)
    return G

G, pos = generate_network(return_positions = True, verbose = True)
# Out:
# Response parameter was set  to: r = 1.0
# Rate parameter was set to:   rate = 1.0646872543081924
# Coupling parameter was set to:  c = 1
# Density parameter was set to: rho = 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hr/pw6v38ln34d_87nsgcx3qjz80000gn/T/ipykernel_69218/3386512452.py in <module>
#       9     return G
#      10
# ---> 11 G, pos = generate_network(return_positions = True, verbose = True)
#
# /var/folders/hr/pw6v38ln34d_87nsgcx3qjz80000gn/T/ipykernel_69218/3386512452.py in generate_network(return_positions, verbose)
#       1 def generate_network(return_positions = False, verbose = False):
# ----> 2     G = rng.network_model(
#       3                     N = N,
#       4                     beta = beta,
#       5                     coupling = coupling,
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/ringity/generators/network_models.py in network_model(N, response, coupling, density, rate, beta, random_state, return_positions, verbose, a, r, c, alpha, rho, K)
#      54         print(f"Density parameter was set to: rho = {network_builder.model_parameters.density}")
#      55
# ---> 56     network_builder.build_model()
#      57
#      58     if verbose:
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/ringity/classes/networkbuilder.py in build_model(self)
#     163             self._build_general_model()
#     164         if self.model_parameters.density == 1:
# --> 165             self.model = "Complete"
#     166             self._build_general_model()
#     167         if self.model_parameters.coupling == 0:
#
# ~/Documents/coding/venvs/ringity/lib/python3.9/site-packages/ringity/classes/networkbuilder.py in model(self, value)
#      79     def model(self, value):
#      80         if hasattr(self, 'model'):
# ---> 81             raise AttributeError(f"Trying to set conflicting models "
#      82                                  f"{value} != {self.model}")
#      83         self._model = value
#
# AttributeError: Trying to set conflicting models Complete != ER_2

# %% [markdown]
# ## Miscellaneous

# %% [markdown]
# ### Max density

# %%
from ringity.network_models.param_utils import max_density

x = np.linspace(0, 1, 100)
y0 = [max_density(0, xi) for xi in x]
y1 = [max_density(1, xi) for xi in x]
y2 = [max_density(2, xi) for xi in x]
yinf = [max_density(np.inf, xi) for xi in x]

plt.plot(x, y0)
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, yinf)
