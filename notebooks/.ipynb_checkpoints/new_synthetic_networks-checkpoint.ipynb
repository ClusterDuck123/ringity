# %% [markdown]
# # Preamble

# %% [markdown]
# To import the module ```ringity``` please make sure that the folder ```/ringity``` is in the same direcotry as this notebook or alternatively download ringity via ```pip install ringity```.

# %% [markdown]
# # Imports

# %%
from scipy.spatial.distance import pdist, squareform
from IPython.display import display, HTML
from mpl_toolkits.mplot3d import Axes3D
from numpy import pi, cos, sin, tan
from collections import Counter, defaultdict

import os
import numpy as np
import pandas as pd
import networkx as nx
import ringity as rng
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
rng.set()

# %% [markdown]
# # Geometric networks

# %%
BLACK = sns.color_palette('bright')[7]

seed = 11092018

# %% [markdown]
# ## Annulus

# %%
# functions needed
def half_circ(x, r=1):
    return np.sqrt(r**2 - x**2)

def sample_annulus(N, 
            r = 1, 
            seed = None):
    """ Outside radius is taken to be 1"""
    
    np.random.seed(seed=seed)
    u,v = np.random.uniform(0,1,[2,N])
    
    phi = 2*np.pi*u
    r = np.sqrt((1-r**2)*v + r**2)
    
    x = r*np.cos(phi)
    y = r*np.sin(phi)
    
    return x,y

# %%
# sample preprocessing
N = 200
r = 0.5

pts = sample_annulus(N=N, r=r, seed=seed)

x_in  = np.linspace(-r,r, 101)
x1 = np.stack((x_in, -x_in)).flatten()
y1 = np.stack((half_circ(x_in, r),-half_circ(x_in, r))).flatten()

x_out = np.linspace(-1,1, 101)
x2 = np.stack((x_out,-x_out)).flatten()
y2 = np.stack((half_circ(x_out),-half_circ(x_out))).flatten()

x_left  = np.linspace(-1,-r, 101)
x_mid   = np.linspace(-r, r, 101)
x_right = np.linspace( r, 1, 101)

phi = np.linspace(-pi,pi,101)
x = (r+0.01)*cos(phi)
y = (r+0.01)*sin(phi)

# %%
# sampling visual
geo_fig, ax = plt.subplots(figsize=(6,6));
ax.axis('off');

ax.plot(pts[0], pts[1], 'o', markersize=1.5, color=rng.CEMM_COL1, alpha=0.8);

ax.plot(x1, y1, color=rng.CEMM_COL4, alpha=0.5);
ax.plot(x2, y2, color=rng.CEMM_COL4, alpha=0.5);
ax.plot(x, y, color='blue', alpha=0.5, linewidth=3);

ax.set_title('Sampled annulus', fontsize=28);

ax.fill_between(x_left, -half_circ(x_left)  , half_circ(x_left),  alpha=0.75, facecolor=rng.CEMM_COL4, edgecolor="none");
ax.fill_between(x_mid,   half_circ(x_mid, r), half_circ(x_mid),   alpha=0.75, facecolor=rng.CEMM_COL4, edgecolor="none");
ax.fill_between(x_mid,  -half_circ(x_mid, r),-half_circ(x_mid),   alpha=0.75, facecolor=rng.CEMM_COL4, edgecolor="none");
ax.fill_between(x_right, half_circ(x_right) ,-half_circ(x_right), alpha=0.75, facecolor=rng.CEMM_COL4, edgecolor="none");

# %%
# network preprocessing
d = 0.5

D = squareform(pdist(np.array(pts).T))
A = np.where(np.abs(D)>d,0,1)
np.fill_diagonal(A,0)
G = nx.from_numpy_array(A)
    
pos = nx.spring_layout(G)

# %%
# network visuals
rng.plot_nx(G, pos=pos)

# %%
degree_sequence = sorted([d for n, d in G.degree()])
degreeCount = Counter(degree_sequence)
degs, cnts = zip(*degreeCount.items())

deg_fig, ax = plt.subplots(figsize=(8,6))
deg_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

ax.bar(degs, cnts, width=1, color='b')

ax.set_xlabel('degree')
ax.set_ylabel('frequency')
ax.set_title('Annulus degree distribution');

ax.tick_params(axis='both', which='major', labelsize=24)

ax.spines['left'].set_linewidth(2.5)
ax.spines['left'].set_color('k')

ax.spines['bottom'].set_linewidth(2.5)
ax.spines['bottom'].set_color('k')

# %%
# calclulate diagrams
dgm   = rng.diagram(D, distance_matrix=True)
dgm_d = rng.diagram(G)

# %%
# persistence visuals
fig, axes = plt.subplots(2, 2, figsize=(14,13))

axes[0,0].set_title('Full Distance Matrix', fontsize=16)
axes[0,1].set_title(f'Cutoff at d={d:.2f}', fontsize=16)

rng.plot_bar(dgm,   ax=axes[0,0], cap=30)
rng.plot_bar(dgm_d, ax=axes[0,1], cap=30)
rng.plot_dgm(dgm,   ax=axes[1,0])
rng.plot_dgm(dgm_d, ax=axes[1,1])

axes[0,0].annotate(f'score = {dgm.score  :.3f}', xy=(0.7, 0.85), xycoords='axes fraction', fontsize=14);
axes[0,1].annotate(f'score = {dgm_d.score:.3f}', xy=(0.7, 0.85), xycoords='axes fraction', fontsize=14);
axes[1,0].annotate(f'score = {dgm.score  :.3f}', xy=(0.7, 0.15), xycoords='axes fraction', fontsize=14);
axes[1,1].annotate(f'score = {dgm_d.score:.3f}', xy=(0.7, 0.15), xycoords='axes fraction', fontsize=14);

# %% [markdown]
# ### Metric analysis

# %%
N = 200  # Number of nodes
r = 0.5  # inner radius
d = 0.5  # threshold

sample_size = 10

# %%
metrics = ['net_flow', 'SPL', 'resistance', 'betweenness', 'current_flow']

# %%
annulus_seq_dicts = defaultdict(list)

for i in range(sample_size):
    pts = sample_annulus(N=N, r=r)

    D = squareform(pdist(np.array(pts).T))
    A = np.where(np.abs(D)>d,0,1)
    np.fill_diagonal(A,0)
    G = nx.from_numpy_array(A)
    
    for metric in metrics:
        dgm = rng.diagram(G, metric=metric).crop(30)
        annulus_seq_dicts[metric].append(list(dgm.sequence))

# %%
for nr, metric in enumerate(metrics):
    fig, ax = plt.subplots()
    rng.ax_setup(ax)
    bars = np.mean(annulus_seq_dicts[metric], axis=0)

    plt.bar(range(len(bars)), bars, color=rng.BAR_COL);
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/annulus_{metric}.png")
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/annulus_{metric}.pdf")
    plt.close()

# %%
fig, axes = plt.subplots(len(metrics), figsize=(5,20))

for nr, metric in enumerate(metrics):
    bars = np.mean(annulus_seq_dicts[metric], axis=0)
    axes[nr].bar(range(len(bars)), bars, color=rng.BAR_COL);
    axes[nr].set_title(metric);
    
plt.tight_layout()

# %% [markdown]
# ## Cylinder

# %%
# functions needed
def sample_cylinder(N,
             height = 1,
             seed = None):
    
    np.random.seed(seed=seed)
    u,v = np.random.uniform(0,1,[2,N])
    
    phi = 2*np.pi*u
    
    x = np.cos(phi)
    y = np.sin(phi)
    z = np.random.uniform(0,height,N)
    
    return x,y,z

# %%
# sample preprocessing
N = 500
h = 3

pts = sample_cylinder(N=N, height=h, seed=seed)

phi    = np.linspace(0, 2*np.pi, 101)
height = np.linspace(0, h, 101)

x = np.outer(np.cos(phi), np.ones(101))
y = np.outer(np.sin(phi), np.ones(101))
z = np.outer(np.ones(101), height)

phi = np.linspace(0,2*pi,101)
x1 = cos(phi)
y1 = sin(phi)
z1 = h/2 * np.ones_like(phi)

# %%
# sampling visual
geo_fig = plt.figure(figsize=(6,6))
ax  = geo_fig.gca(projection='3d')
ax.set_xlim(-h,h)
ax.set_ylim(-h,h)
ax.set_zlim(0,h)
ax.set_facecolor('white')
ax.axis('off')

ax.set_title('Sampled cylinder', fontsize=28);

ax.plot(pts[0],pts[1], pts[2], 'o', markersize=1, color=rng.CEMM_COL1);
ax.plot_surface(x, y, z, color=rng.CEMM_COL4, alpha=0.25, linewidth=0.1, edgecolors=rng.CEMM_COL2 + [0.5]);
ax.plot(x1, y1, z1, 'b', linewidth=3);

# %%
# network preprocessing
d = 0.75

D = squareform(pdist(np.array(pts).T))
A = np.where(np.abs(D)>d,0,1)
np.fill_diagonal(A,0)
G = nx.from_numpy_array(A)
    
pos = nx.spring_layout(G)

# %%
# network visuals
rng.plot_nx(G, pos=pos)

# %%
degree_sequence = sorted([d for n, d in G.degree()])
degreeCount = Counter(degree_sequence)
degs, cnts = zip(*degreeCount.items())

deg_fig, ax = plt.subplots(figsize=(8,6))
deg_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

ax.bar(degs, cnts, width=1, color='b')

ax.set_xlabel('degree', fontsize=24)
ax.set_ylabel('frequency', fontsize=24)
ax.set_title('Cylinder degree distribution', fontsize=28);

rng.ax_setup(ax)

# %%
# calclulate diagrams
dgm   = rng.diagram(D, distance_matrix=True)
dgm_d = rng.diagram(G)

# %%
# persistence visuals
fig, axes = plt.subplots(2, 2, figsize=(14,13))

axes[0,0].set_title('Full Distance Matrix', fontsize=16)
axes[0,1].set_title(f'Cutoff at d={d:.2f}', fontsize=16)

rng.plot_bar(dgm,   ax=axes[0,0], cap=30)
rng.plot_bar(dgm_d, ax=axes[0,1], cap=30)
rng.plot_dgm(dgm,   ax=axes[1,0])
rng.plot_dgm(dgm_d, ax=axes[1,1])

axes[0,0].annotate(f'score = {dgm.score  :.3f}', xy=(0.7, 0.85), xycoords='axes fraction', fontsize=14);
axes[0,1].annotate(f'score = {dgm_d.score:.3f}', xy=(0.7, 0.85), xycoords='axes fraction', fontsize=14);
axes[1,0].annotate(f'score = {dgm.score  :.3f}', xy=(0.7, 0.15), xycoords='axes fraction', fontsize=14);
axes[1,1].annotate(f'score = {dgm_d.score:.3f}', xy=(0.7, 0.15), xycoords='axes fraction', fontsize=14);

# %% [markdown]
# ### Metric analysis

# %%
N = 500  # Number of nodes
h = 3    # Hight
d = 0.7  # Threshold

sample_size = 10

# %%
metrics = ['net_flow', 'SPL', 'resistance', 'betweenness', 'current_flow']

# %%
cylinder_seq_dicts = defaultdict(list)

for i in range(sample_size):
    pts = sample_cylinder(N=N, height=h)

    D = squareform(pdist(np.array(pts).T))
    A = np.where(np.abs(D)>d,0,1)
    np.fill_diagonal(A,0)
    G = nx.from_numpy_array(A)
    
    for metric in metrics:
        dgm = rng.diagram(G, metric=metric).crop(30)
        cylinder_seq_dicts[metric].append(list(dgm.sequence))

# %%
for nr, metric in enumerate(metrics):    
    fig, ax= plt.subplots()
    rng.ax_setup(ax)
    bars = np.mean(cylinder_seq_dicts[metric], axis=0)
    plt.bar(range(len(bars)), bars, color=rng.BAR_COL);
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/cylinder_{metric}.png")
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/cylinder_{metric}.pdf")
    plt.close()

# %%
fig, axes = plt.subplots(len(metrics), figsize=(5,20))

for nr, metric in enumerate(metrics):
    bars = np.mean(cylinder_seq_dicts[metric], axis=0)
    axes[nr].bar(range(len(bars)), bars, color=rng.BAR_COL);
    axes[nr].set_title(metric);
    
plt.tight_layout()

# %% [markdown]
# ## Torus

# %%
# functions needed
def sample_torus(N,
        inner_radius  = 1,
        seed = None):
    "The circle of revolution is assumed to be 1"
    
    np.random.seed(seed=seed)
    u,v = np.random.uniform(0,2*np.pi,[2,N])
    
    x = (1 + r*np.cos(v))*np.cos(u)
    y = (1 + r*np.cos(v))*np.sin(u)
    z = r*np.sin(v)
    
    return x,y,z

# %%
# sample preprocessing
N  = 750
r = 1/2

pts = sample_torus(N=N, inner_radius=r, seed=seed)

u = np.linspace(0,2*np.pi,101)
v = np.linspace(0,2*np.pi,101)

x = np.outer(1 + r*np.cos(v), np.cos(u))
y = np.outer(1 + r*np.cos(v), np.sin(u))
z = np.outer(np.sin(v), r*np.ones(101))

u11 = pi
v11 = np.linspace(0.5,pi+0.7,101)
x11 = cos(v11)*(1 + r*cos(u11))
y11 = sin(v11)*(1 + r*cos(u11))
z11 = r*np.sin(u11)

u12 = u11
v12 = np.linspace(-pi, pi, 101)
x12 = cos(v12)*(1 + r*cos(u12))
y12 = sin(v12)*(1 + r*cos(u12))
z12 = r*np.sin(u12)

u2 = np.linspace(0,2*pi,101)
v2 = -0.1
x2 = cos(v2)*(1 + r*cos(u2))
y2 = sin(v2)*(1 + r*cos(u2))
z2 = r*np.sin(u2)

# %%
# sampling visual
geo_fig = plt.figure(figsize=(8,8))
ax = plt.gca(projection='3d')
ax.set_xlim(-1-r,1+r)
ax.set_ylim(-1-r,1+r)
ax.set_zlim(-1,1)
ax.set_facecolor('white')
ax.axis('off')


ax.set_title('Sampled torus', fontsize=28);

ax.plot_surface(x, y, z, color=rng.CEMM_COL4, alpha=0.4, linewidth=0.1, edgecolors=rng.CEMM_COL2 + [0.5])
ax.plot(pts[0],pts[1], pts[2], 'ko', markersize=1, color=rng.CEMM_COL1);
# ax.plot(x12, y12, z12, 'b--', linewidth=3, alpha = 1);
ax.plot(x12, y12, z12, 'b', linewidth=3, alpha = 1);
ax.plot(x11, y11, z11, 'blue', linewidth=3, alpha = 0.5);
ax.plot(x2, y2, z2, 'red' , linewidth=3, alpha = 0.5);

ax.view_init(elev=60)

# %%
# network preprocessing
d = 0.6

D = squareform(pdist(np.array(pts).T))
A = np.where(np.abs(D)>d,0,1)
np.fill_diagonal(A,0)
G = nx.from_numpy_array(A)
    
pos = nx.spring_layout(G)

# %%
# network visuals
rng.plot_nx(G, pos=pos)

# %%
degree_sequence = sorted([d for n, d in G.degree()])
degreeCount = Counter(degree_sequence)
degs, cnts = zip(*degreeCount.items())

deg_fig, ax = plt.subplots(figsize=(8,6))
deg_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

ax.bar(degs, cnts, width=1, color='b')

ax.set_xlabel('degree', fontsize=24)
ax.set_ylabel('frequency', fontsize=24)
ax.set_title('Torus degree distribution', fontsize=28);

rng.ax_setup(ax)

# %%
# calclulate diagrams
dgm   = rng.diagram(D, distance_matrix=True)
dgm_d = rng.diagram(G)

# %%
# persistence visuals
fig, axes = plt.subplots(2, 2, figsize=(14,13))

axes[0,0].set_title('Full Distance Matrix', fontsize=16)
axes[0,1].set_title(f'Cutoff at d={d:.2f}', fontsize=16)

rng.plot_bar(dgm,   ax=axes[0,0], cap=30)
rng.plot_bar(dgm_d, ax=axes[0,1], cap=30)
rng.plot_dgm(dgm,   ax=axes[1,0])
rng.plot_dgm(dgm_d, ax=axes[1,1])

axes[0,0].annotate(f'score = {dgm.score  :.3f}', xy=(0.7, 0.85), xycoords='axes fraction', fontsize=14);
axes[0,1].annotate(f'score = {dgm_d.score:.3f}', xy=(0.7, 0.85), xycoords='axes fraction', fontsize=14);
axes[1,0].annotate(f'score = {dgm.score  :.3f}', xy=(0.7, 0.15), xycoords='axes fraction', fontsize=14);
axes[1,1].annotate(f'score = {dgm_d.score:.3f}', xy=(0.7, 0.15), xycoords='axes fraction', fontsize=14);

# %% [markdown]
# ### Different metric

# %%
N = 1000   # Number of nodes
r = 1/2   # Inner radius
d = 0.6   # Threshold

sample_size = 10

# %%
pts = sample_torus(N=N, inner_radius=r)

D = squareform(pdist(np.array(pts).T))
A = np.where(np.abs(D)>d,0,1)
np.fill_diagonal(A,0)
G = nx.from_numpy_array(A)
print(nx.density(G))
pos = nx.spring_layout(G)
rng.plot_nx(G, pos=pos)
# Out:
# 0.07128728728728728

# %%
dgm = rng.diagram(G).crop(30)
rng.plot_bar(dgm)

# %%
metrics = ['net_flow', 'SPL', 'resistance', 'betweenness']

# %%
torus_seq_dicts = defaultdict(list)

for i in range(sample_size):
    pts = sample_torus(N=N, inner_radius=r)

    D = squareform(pdist(np.array(pts).T))
    A = np.where(np.abs(D)>d,0,1)
    np.fill_diagonal(A,0)
    G = nx.from_numpy_array(A)
    
    for metric in metrics:
        dgm = rng.diagram(G, metric=metric).crop(30)
        if dgm.signal == 0:
            continue
        torus_seq_dicts[metric].append(list(dgm.sequence))

# %%
for nr, metric in enumerate(metrics):    
    fig, ax= plt.subplots()
    rng.ax_setup(ax)
    bars = np.mean(torus_seq_dicts[metric], axis=0)
    plt.bar(range(len(bars)), bars, color=rng.BAR_COL);
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/torus_{metric}.png")
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/torus_{metric}.pdf")
    plt.close()

# %%
fig, axes = plt.subplots(len(metrics), figsize=(5,18))

for nr, metric in enumerate(metrics):
    bars = np.mean(torus_seq_dicts[metric], axis=0)
    axes[nr].bar(range(len(bars)), bars, color=rng.BAR_COL);
    axes[nr].set_title(metric);
    
plt.tight_layout()

# %%
pts = sample_annulus(N=200, r=1/2)
D = squareform(pdist(np.array(pts).T))
A = np.where(np.abs(D)>0.5,0,1)
np.fill_diagonal(A,0)
G_ann = nx.from_numpy_array(A)

pos_ann = nx.spring_layout(G_ann)

# %%
pts = sample_cylinder(N=500, height=3)
D = squareform(pdist(np.array(pts).T))
A = np.where(np.abs(D)>0.75,0,1)
np.fill_diagonal(A,0)
G_cyl = nx.from_numpy_array(A)

pos_cyl = nx.spring_layout(G_cyl)

# %%
pts = sample_torus(N=750, inner_radius=1/2)
D = squareform(pdist(np.array(pts).T))
A = np.where(np.abs(D)>0.5,0,1)
np.fill_diagonal(A,0)
G_tor = nx.from_numpy_array(A)

pos_tor = nx.spring_layout(G_tor)

# %%
fig, axes = plt.subplots(5,3, figsize=(12,18))

rng.plot_nx(G_ann, ax=axes[0,0], pos=pos_ann)
axes[0,0].set_title("Annulus");
rng.plot_nx(G_cyl, ax=axes[0,1], pos=pos_cyl)
axes[0,1].set_title("Cylinder");
rng.plot_nx(G_tor, ax=axes[0,2], pos=pos_tor)
axes[0,2].set_title("Torus");

for nr, metric in enumerate(metrics, 1):
    bars = np.mean(annulus_seq_dicts[metric], axis=0)
    ax = axes[nr,0]
    ax.bar(range(len(bars)), bars, color=rng.BAR_COL);
    ax.set_ylabel(metric);
    rng.ax_setup(ax)
    
for nr, metric in enumerate(metrics, 1):
    bars = np.mean(cylinder_seq_dicts[metric], axis=0)
    ax = axes[nr,1]
    ax.bar(range(len(bars)), bars, color=rng.BAR_COL);
    rng.ax_setup(ax)
    
for nr, metric in enumerate(metrics, 1):
    bars = np.mean(torus_seq_dicts[metric], axis=0)
    ax = axes[nr,2]
    ax.bar(range(len(bars)), bars, color=rng.BAR_COL);
    rng.ax_setup(ax)
    
plt.tight_layout()

plt.savefig(f"/Users/markusyoussef/Desktop/figures/all_geometries.png")
plt.savefig(f"/Users/markusyoussef/Desktop/figures/all_geometries.pdf")

# %%
for metric in metrics:
    print(metric, len(torus_seq_dicts[metric]))
# Out:
# net_flow 10
# SPL 10
# resistance 2
# betweenness 10

# %% [markdown]
# # Model networks

# %% [markdown]
# ### Watts-Strogatz metric analysis

# %%
N = 1000
k = 10
p_list = [0, 0.01, 0.1, 1]

sample_size = 10

ws_seq_dicts = {}

for p in p_list:
    ws_seq_dicts[p] = defaultdict(list)
    
    for i in range(sample_size):
        G = nx.watts_strogatz_graph(N,k,p)
        for metric in metrics:
            dgm = rng.diagram(G, metric=metric).crop(30)
            if dgm.signal == 0:
                continue
            ws_seq_dicts[p][metric].append(list(dgm.sequence))

# %%
G_list = [nx.watts_strogatz_graph(N,k,p) for p in p_list]
pos = {n:(np.cos(t), np.sin(t)) for (n,t) in enumerate(np.linspace(0,2*np.pi,N+1))}

# %%
fig, axes = plt.subplots(5,4, figsize=(20,18))

for nr,(G,p) in enumerate(zip(G_list,p_list)):
    rng.plot_nx(G, ax=axes[0,nr], pos=pos)
    axes[0,nr].set_title(f"WS({N},{k},{p:.2f})");

for column, p in enumerate(p_list):
    for row, metric in enumerate(metrics, 1):
        bars = np.mean(ws_seq_dicts[p][metric], axis=0)
        ax = axes[row,column]
        ax.bar(range(len(bars)), bars, color=rng.BAR_COL);
        rng.ax_setup(ax)
        if column == 0:
            ax.set_ylabel(metric);
    
plt.tight_layout()

plt.savefig(f"/Users/markusyoussef/Desktop/figures/all_watts_strogatz.png")
plt.savefig(f"/Users/markusyoussef/Desktop/figures/all_watts_strogatz.pdf")

# %%
for p, metric in product(p_list,metrics):    
    fig, ax= plt.subplots()
    rng.ax_setup(ax)
    bars = np.mean(ws_seq_dicts[p][metric], axis=0)
    plt.bar(range(len(bars)), bars, color=rng.BAR_COL);
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/ws{p:.2f}_{metric}.png")
    plt.savefig(f"/Users/markusyoussef/Desktop/figures/ws{p:.2f}_{metric}.pdf")
    plt.close()

# %%
for p,metric in product(p_list,metrics):
    print(metric, p)
    print(len(ws_seq_dicts[p][metric]))
    print()
# Out:
# net_flow 0
# 10
#
# SPL 0
# 10
#
# resistance 0
# 10
#
# betweenness 0
# 10
#
# net_flow 0.01
# 10
#
# SPL 0.01
# 10
#
# resistance 0.01
# 10
#
# betweenness 0.01
# 10
#
# net_flow 0.1
# 10
#
# SPL 0.1
# 10
#
# resistance 0.1
# 10
#
# betweenness 0.1
# 10
#
# net_flow 1
# 10
#
# SPL 1
# 10
#
# resistance 1
# 3
#
# betweenness 1
# 10

# %% [markdown]
# ## Watts-Strogatz (individuals)

# %%
# Set parameters
N = 1000
k = 10

p_list = [0, 0.01, 0.1, 1]
G_list = [nx.watts_strogatz_graph(N,k,p) for p in p_list]

pos = {n:(np.cos(t), np.sin(t)) for (n,t) in enumerate(np.linspace(0,2*np.pi,N+1))}

# %%
# get those data!
path = f'data/toy_networks/watts_strogatz/dgms/N{N}/k{k}'
dgm_dict = {p:[] for p in p_list}

for p in p_list:
    for file in os.listdir(f'{path}/p{p:.6f}'):
        if not file.endswith('.csv'):
            continue
        dgm = rng.load_dgm(f'{path}/p{p:.6f}/{file}')
        for i in range(50): dgm.append((0,0))
        dgm_dict[p].append(rng.normalize(dgm))
        
dgm_list = [np.mean(dgm_dict[p]) for p in p_list]
# Out:
# -----------------------------------------------------------
# FileNotFoundError         Traceback (most recent call last)
# <ipython-input-48-4f44b66fc6fe> in <module>
#       4
#       5 for p in p_list:
# ----> 6     for file in os.listdir(f'{path}/p{p:.6f}'):
#       7         if not file.endswith('.csv'):
#       8             continue
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/toy_networks/watts_strogatz/dgms/N1000/k10/p0.000000'

# %%
# somehow for p=0 things don't work properly...
file = os.listdir(f'{path}/p{0:.6f}')[0]
dgm = rng.load_dgm(f'{path}/p{0:.6f}/{file}')
dgm_list[0] = rng.normalize(dgm)
# Out:
# -----------------------------------------------------------
# FileNotFoundError         Traceback (most recent call last)
# <ipython-input-49-e64abcf96aa5> in <module>
#       1 # somehow for p=0 things don't work properly...
# ----> 2 file = os.listdir(f'{path}/p{0:.6f}')[0]
#       3 dgm = rng.load_dgm(f'{path}/p{0:.6f}/{file}')
#       4 dgm_list[0] = rng.normalize(dgm)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/toy_networks/watts_strogatz/dgms/N1000/k10/p0.000000'

# %%
# persistence visuals
fig, axes = plt.subplots(len(p_list), 3, figsize=(13,16))

for i in range(len(p_list)):
    plot_nx(G_list[i], pos=pos, ax=axes[i,0], edge_alpha=(1-i/4)/2)
    plot_bar(dgm_list[i], ax=axes[i,1], cap=30)
    plot_dgm(dgm_list[i], ax=axes[i,2])
    
    axes[i,1].annotate(f'score = {dgm_list[i].GGS:.3f}', xy=(0.65, 0.925), xycoords='axes fraction', fontsize=10);
    axes[i,2].annotate(f'score = {dgm_list[i].GGS:.3f}', xy=(0.65, 0.12), xycoords='axes fraction', fontsize=10);

# %% [markdown]
# ## Watts-Strogatz (curves)

# %%
# Some preprocessing
N = 2**10

k_list = [8, 10, 12]
p_lists = []
score_lists = []

for k in k_list:
    df = pd.read_csv(f'data/toy_networks/watts_strogatz/GGS/N{N}/k{k}/GGS.csv', index_col=0).mean()
    p_lists.append(np.array(df.index.astype(float)))
    score_lists.append(np.array(df))

# %%
# Aaaand here the visuals
rand_fig, ax = plt.subplots(figsize=(10,8))
rand_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

for i,k in enumerate(k_list):
    ax.semilogy(p_lists[i], score_lists[i], label=f'k={k}', linewidth=2.5)
    
ax.legend(fontsize=28, shadow=True, facecolor=[0.95, 0.95, 0.95, 0])
# ax.set_title(f'Watts-Strogatz scores for N={N}', fontsize=24);

ax.tick_params(axis='both', which='major', labelsize=24)

ax.spines['left'].set_linewidth(2.5)
ax.spines['left'].set_color(sblack2)

ax.spines['bottom'].set_linewidth(2.5)
ax.spines['bottom'].set_color(sblack2)

# %% [markdown]
# ## Erdos-Renyi (annealing)

# %%
# Some preprocessing
N = 2**8
df = pd.read_csv(f'data/toy_networks/erdos_renyi/ER_analysis/GGS/{N}.csv', index_col=0)
df.columns = df.columns.astype(float)

dfa = pd.read_csv(f'data/toy_networks/erdos_renyi/ER_annealing_10000/GGS/{N}.csv', index_col=0)
dfa.columns = dfa.columns.astype(float)

df = df.iloc[:,df.columns<=0.1]

x      = np.array(list(map(float,df.keys())))
y_25   = np.array(df.describe().loc['25%'])
y_mean = np.array(df.describe().loc['mean'])
y_75   = np.array(df.describe().loc['75%'])

xa      = np.array(list(map(float,dfa.keys())))
ya_25   = np.array(dfa.describe().loc['25%'])
ya_mean = np.array(dfa.describe().loc['mean'])
ya_75   = np.array(dfa.describe().loc['75%'])

# %%
dens_fig, ax = plt.subplots(figsize=(15,10))
dens_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

ax.plot(x, y_mean,'--', label='        0 iterations', color=sblue, linewidth=2.5);
ax.fill_between(x, y_25 , y_75 , alpha=0.1, color=sblue);

ax.plot(xa, ya_mean, color='blue', label='10000 iterations', linewidth=2.5);
ax.fill_between(xa, ya_25 , ya_75 , alpha=0.1, color='blue');

# ax.set_xlabel('density')
# ax.set_ylabel('score')
ax.legend(fontsize=28, shadow=True, facecolor=[0.95, 0.95, 0.95, 0])
# ax.set_title(r'ER$\left(2^8,p\right)$ annealed scores', fontsize=24);

ax.tick_params(axis='both', which='major', labelsize=24)

ax.spines['left'].set_linewidth(2.5)
ax.spines['left'].set_color(sblack2)

ax.spines['bottom'].set_linewidth(2.5)
ax.spines['bottom'].set_color(sblack2)

# %%
p = '0.090000'
path = f'data/toy_networks/erdos_renyi/ER_annealing_10000/datas/N{N}/p{p}'
data = np.zeros(10000)

for i, file in enumerate(os.listdir(f'{path}')):
    data += np.genfromtxt(f'{path}/{file}')
data = data/i

# %%
iter_fig, ax = plt.subplots(figsize=(15,10))
iter_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

ax.plot(data, linewidth=2.5);
ax.set_xlabel('iteration')
ax.set_ylabel('score')
ax.set_title('Typical (i.e. average) annealing progress for 10000 iterations', fontsize=24);

ax.tick_params(axis='both', which='major', labelsize=24)

ax.spines['left'].set_linewidth(2.5)
ax.spines['left'].set_color(sblack2)

ax.spines['bottom'].set_linewidth(2.5)
ax.spines['bottom'].set_color(sblack2)

# %% [markdown]
# ## Erdos_Renyi (density)

# %%
N = 2**7
df0 = pd.read_csv(f'data/toy_networks/erdos_renyi/ER_analysis/GGS/{N}.csv', index_col=0)
df0.columns = df0.columns.astype(float)

N = 2**8
df1 = pd.read_csv(f'data/toy_networks/erdos_renyi/ER_analysis/GGS/{N}.csv', index_col=0)
df1.columns = df1.columns.astype(float)

N = 2**9
df2 = pd.read_csv(f'data/toy_networks/erdos_renyi/ER_analysis/GGS/{N}.csv', index_col=0)
df2.columns = df2.columns.astype(float)

N = 2**10
df3 = pd.read_csv(f'data/toy_networks/erdos_renyi/ER_analysis/GGS/{N}.csv', index_col=0)
df3.columns = df3.columns.astype(float)

# %% [markdown]
# ## Barabasi-Albert (annealing)

# %%
N = 2**8

df = pd.read_csv(f'data/toy_networks/barabasi_albert/BA_analysis/GGS/{N}.csv', index_col=0)
df.columns = df.columns.astype(int)

dfa = pd.read_csv(f'data/toy_networks/barabasi_albert/BA_annealing_10000/GGS/{N}.csv', index_col=0)
dfa.columns = dfa.columns.astype(int)

df  = df.iloc[:,df.columns   < 14]
dfa = dfa.iloc[:,dfa.columns < 14]

x      = np.array(list(map(int,df.keys())))
y_25   = np.array(df.describe().loc['25%'])
y_mean = np.array(df.describe().loc['mean'])
y_75   = np.array(df.describe().loc['75%'])

xa      = np.array(list(map(int,dfa.keys())))
ya_25   = np.array(dfa.describe().loc['25%'])
ya_mean = np.array(dfa.describe().loc['mean'])
ya_75   = np.array(dfa.describe().loc['75%'])

# %%
dens_fig, ax = plt.subplots(figsize=(15,10))
dens_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

ax.plot(x, y_mean,'--', label='        0 iterations', color=sblue, linewidth=2.5);
ax.fill_between(x, y_25 , y_75 , alpha=0.1, color=sblue);

ax.plot(xa, ya_mean, color='blue', label='10000 iterations', linewidth=2.5);
ax.fill_between(xa, ya_25 , ya_75 , alpha=0.1, color='blue');

# ax.set_xlabel('m')
# ax.set_ylabel('score')
ax.legend(fontsize=28, shadow=True, facecolor=[0.95, 0.95, 0.95, 0])
# ax.set_title(r'BA$\left(2^8,p\right)$ annealed scores', fontsize=24);

ax.tick_params(axis='both', which='major', labelsize=24)

ax.spines['left'].set_linewidth(2.5)
ax.spines['left'].set_color(sblack2)

ax.spines['bottom'].set_linewidth(2.5)
ax.spines['bottom'].set_color(sblack2)

# %%
m = 4
path = f'data/toy_networks/barabasi_albert/BA_annealing_10000/datas/N{N}/m{m}'
data = np.zeros(10000)

for i, file in enumerate(os.listdir(f'{path}')):
    data += np.genfromtxt(f'{path}/{file}')
data = data/i

# %%
iter_fig, ax = plt.subplots(figsize=(15,10))
iter_fig.patch.set_alpha(0)
ax.patch.set_alpha(0)

ax.plot(data, linewidth=2.5);
ax.set_xlabel('iteration')
ax.set_ylabel('score')
ax.set_title('Typical (i.e. average) annealing progress for 10000 iterations', fontsize=24);

ax.tick_params(axis='both', which='major', labelsize=24)

ax.spines['left'].set_linewidth(2.5)
ax.spines['left'].set_color(sblack2)

ax.spines['bottom'].set_linewidth(2.5)
ax.spines['bottom'].set_color(sblack2)
