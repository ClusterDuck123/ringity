# %%
import igraph
import string
import ringity as rng
import networkx as nx

# %%
G = nx.barabasi_albert_graph(2**10, 3)

# %%
bb = rng.net_flow(G)

# %%
D = rng.resistance(G)

# %%
g = igraph.Graph()
g.add_vertices([0, 1, 2])

# %%
print(g)
# Out:
# IGRAPH UN-- 3 0 --
# + attr: name (v)

# %%
g.add_edges([(2, 0)])

# %%
print(g)
# Out:
# IGRAPH UN-- 3 1 --
# + attr: name (v)
# + edges (vertex names):
# 0--2

# %%
g = igraph.Graph.Tree(10,2)
g.vs['label'] = list(string.ascii_uppercase[:10])

layout = g.layout("kk")
igraph.plot(g, layout=layout, label='name')

# %%
N = 20
g = igraph.Graph.Tree(N,2)
g.vs['label'] = list(string.ascii_uppercase[:N])

layout = g.layout("kk")
igraph.plot(g, layout=layout, label='name')
